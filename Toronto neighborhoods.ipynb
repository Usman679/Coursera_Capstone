# %%
import pandas as pd

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.5.0-cp37-cp37m-manylinux1_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 3.3 MB/s eta 0:00:01     |██████████████                  | 2.5 MB 3.3 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.0.1-py2.py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from html5lib) (1.14.0)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 3.5 MB/s eta 0:00:01
# Collecting soupsieve>=1.2
#   Downloading soupsieve-2.0-py2.py3-none-any.whl (32 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.8.2 soupsieve-2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas.io.html import read_html
page = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
wikitables = read_html(page,  attrs={"class":"wikitable"})

# %%
print ('Extracted {num} wikitables'.format(num=len(wikitables)))
# Out:
# Extracted 1 wikitables

# %%
wikitables[0].head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
df = wikitables[0]

# %%
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
df.drop(df.loc[df['Borough']=='Not assigned'].index, inplace=True)

# %%
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
 df['Postal code'].groupby([ df.Borough, df.Neighborhood,]).apply(list).reset_index()
# Out:
#              Borough                                       Neighborhood  \
# 0    Central Toronto                                         Davisville
# 1    Central Toronto                                   Davisville North
# 2    Central Toronto                           Forest Hill North & West
# 3    Central Toronto                                      Lawrence Park
# 4    Central Toronto                       Moore Park / Summerhill East
# 5    Central Toronto                                 North Toronto West
# 6    Central Toronto                                           Roselawn
# 7    Central Toronto  Summerhill West / Rathnelly / South Hill / For...
# 8    Central Toronto              The Annex / North Midtown / Yorkville
# 9   Downtown Toronto                                        Berczy Park
# 10  Downtown Toronto  CN Tower / King and Spadina / Railway Lands / ...
# 11  Downtown Toronto                                 Central Bay Street
# 12  Downtown Toronto                                           Christie
# 13  Downtown Toronto                               Church and Wellesley
# 14  Downtown Toronto                    Commerce Court / Victoria Hotel
# 15  Downtown Toronto            First Canadian Place / Underground city
# 16  Downtown Toronto                           Garden District, Ryerson
# 17  Downtown Toronto  Harbourfront East / Union Station / Toronto Is...
# 18  Downtown Toronto        Kensington Market / Chinatown / Grange Park
# 19  Downtown Toronto       Queen's Park / Ontario Provincial Government
# 20  Downtown Toronto                         Regent Park / Harbourfront
# 21  Downtown Toronto                         Richmond / Adelaide / King
# 22  Downtown Toronto                                           Rosedale
# 23  Downtown Toronto                                     St. James Town
# 24  Downtown Toronto                       St. James Town / Cabbagetown
# 25  Downtown Toronto                                     Stn A PO Boxes
# 26  Downtown Toronto          Toronto Dominion Centre / Design Exchange
# 27  Downtown Toronto                    University of Toronto / Harbord
# 28      East Toronto              Business reply mail Processing CentrE
# 29      East Toronto                    India Bazaar / The Beaches West
# ..               ...                                                ...
# 68        North York                          York Mills / Silver Hills
# 69        North York                                    York Mills West
# 70       Scarborough                                          Agincourt
# 71       Scarborough                       Birch Cliff / Cliffside West
# 72       Scarborough                                          Cedarbrae
# 73       Scarborough          Clarks Corners / Tam O'Shanter / Sullivan
# 74       Scarborough  Cliffside / Cliffcrest / Scarborough Village West
# 75       Scarborough  Dorset Park / Wexford Heights / Scarborough To...
# 76       Scarborough                  Golden Mile / Clairlea / Oakridge
# 77       Scarborough                Guildwood / Morningside / West Hill
# 78       Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 79       Scarborough                                    Malvern / Rouge
# 80       Scarborough  Milliken / Agincourt North / Steeles East / L'...
# 81       Scarborough           Rouge Hill / Port Union / Highland Creek
# 82       Scarborough                                Scarborough Village
# 83       Scarborough                     Steeles West / L'Amoreaux West
# 84       Scarborough                                        Upper Rouge
# 85       Scarborough                                 Wexford / Maryvale
# 86       Scarborough                                             Woburn
# 87      West Toronto     Brockton / Parkdale Village / Exhibition Place
# 88      West Toronto                      Dufferin / Dovercourt Village
# 89      West Toronto                     High Park / The Junction South
# 90      West Toronto                          Little Portugal / Trinity
# 91      West Toronto                            Parkdale / Roncesvalles
# 92      West Toronto                                Runnymede / Swansea
# 93              York                                Caledonia-Fairbanks
# 94              York  Del Ray / Mount Dennis / Keelsdale and Silvert...
# 95              York                                 Humewood-Cedarvale
# 96              York                     Runnymede / The Junction North
# 97              York                                             Weston
#
#    Postal code
# 0        [M4S]
# 1        [M4P]
# 2        [M5P]
# 3        [M4N]
# 4        [M4T]
# 5        [M4R]
# 6        [M5N]
# 7        [M4V]
# 8        [M5R]
# 9        [M5E]
# 10       [M5V]
# 11       [M5G]
# 12       [M6G]
# 13       [M4Y]
# 14       [M5L]
# 15       [M5X]
# 16       [M5B]
# 17       [M5J]
# 18       [M5T]
# 19       [M7A]
# 20       [M5A]
# 21       [M5H]
# 22       [M4W]
# 23       [M5C]
# 24       [M4X]
# 25       [M5W]
# 26       [M5K]
# 27       [M5S]
# 28       [M7Y]
# 29       [M4L]
# ..         ...
# 68       [M2L]
# 69       [M2P]
# 70       [M1S]
# 71       [M1N]
# 72       [M1H]
# 73       [M1T]
# 74       [M1M]
# 75       [M1P]
# 76       [M1L]
# 77       [M1E]
# 78       [M1K]
# 79       [M1B]
# 80       [M1V]
# 81       [M1C]
# 82       [M1J]
# 83       [M1W]
# 84       [M1X]
# 85       [M1R]
# 86       [M1G]
# 87       [M6K]
# 88       [M6H]
# 89       [M6P]
# 90       [M6J]
# 91       [M6R]
# 92       [M6S]
# 93       [M6E]
# 94       [M6M]
# 95       [M6C]
# 96       [M6N]
# 97       [M9N]
#
# [98 rows x 3 columns]
